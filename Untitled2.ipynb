# %%
import numpy as np
import os
import cv2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt

# %%
genuine_path = './signatures/full_org/' 
forged_path = './signatures/full_forg/'  

img_size = 224  
genuine_label, forged_label = 0, 1  

data, labels = [], []
for file in os.listdir(genuine_path):
    image = cv2.imread(os.path.join(genuine_path, file))
    if image is not None:
        image = cv2.resize(image, (img_size, img_size))
        data.append(image)
        labels.append(genuine_label)

for file in os.listdir(forged_path):
    image = cv2.imread(os.path.join(forged_path, file))
    if image is not None:
        image = cv2.resize(image, (img_size, img_size))
        data.append(image)
        labels.append(forged_label)

data = np.array(data, dtype="float32") / 255.0
labels = np.array(labels)

# %%
train_data, test_data, train_labels, test_labels = train_test_split(data, labels, test_size=0.2, random_state=42)

train_labels = to_categorical(train_labels, num_classes=2)
test_labels = to_categorical(test_labels, num_classes=2)

# %%
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(img_size, img_size, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(2, activation='sigmoid')
    ])
model.compile(optimizer=Adam(learning_rate=0.001), loss="categorical_crossentropy", metrics=["accuracy"])
model.summary()
# Out:
# C:\Users\HP\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 222, 222, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 111, 111, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
EPOCHS = 10
BS = 8
progess = model.fit(train_data,train_labels, batch_size=BS,epochs=EPOCHS)
# Out:
# Epoch 1/10
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 127s 454ms/step - accuracy: 0.5334 - loss: 0.8307
# Epoch 2/10
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 118s 446ms/step - accuracy: 0.5166 - loss: 0.6930
# Epoch 3/10
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 118s 447ms/step - accuracy: 0.4734 - loss: 0.6936
# Epoch 4/10
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 122s 464ms/step - accuracy: 0.5071 - loss: 0.6932
# Epoch 5/10
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 116s 441ms/step - accuracy: 0.4858 - loss: 0.6935
# Epoch 6/10
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 148s 461ms/step - accuracy: 0.4813 - loss: 0.6934
# Epoch 7/10
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 142s 462ms/step - accuracy: 0.4670 - loss: 0.6938
# Epoch 8/10
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 146s 553ms/step - accuracy: 0.5152 - loss: 0.6931
# Epoch 9/10
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 213s 590ms/step - accuracy: 0.5014 - loss: 0.6935
# Epoch 10/10
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 189s 540ms/step - accuracy: 0.5134 - loss: 0.6929

# %%
acc = progess.history['accuracy']
loss = progess.history['loss']

epochs = range(len(acc))

# Plot training accuracy
plt.figure()
plt.plot(epochs, acc, 'b', label='Training Accuracy')
plt.title('Training Accuracy')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()

# Plot training loss
plt.figure()
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.title('Training Loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
pred = model.predict(test_data)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 423ms/step

# %%
pred
# Out:
# array([[0.8398808 , 0.60678756],
#        [0.9464858 , 0.36819044],
#        [0.99644756, 0.01241438],
#        ...,
#        [0.43412107, 0.9023223 ],
#        [0.08500277, 0.99956185],
#        [0.65402174, 0.98901737]], dtype=float32)

# %%
from sklearn.metrics import accuracy_score
import numpy as np

true_labels = np.argmax(test_labels, axis=1)

accuracy = accuracy_score(true_labels, pred.argmax(axis=1))
print("Test Accuracy:", accuracy)
# Out:
# Test Accuracy: 0.8636363636363636
